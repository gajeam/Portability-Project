# %%
ABOUT__FACE_RECOGNITION = "about_you/face_recognition.json"
ABOUT__FRIEND_PEER_GROUP = "about_you/friend_peer_group.json"
ABOUT__ADDRESS_BOOK = "about_you/your_address_books.json"

ADS__INTERESTS = "ads/ads_interests.json"
ADS__UPLOADED_CONTACT_LIST = "ads/advertisers_who_uploaded_a_contact_list_with_your_information.json"
ADS__INTERACTED_WITH = "ads/advertisers_you've_interacted_with.json"

APPS_AND_WEBSITES = 'apps_and_websites/apps_and_websites.json'

COMMENTS = 'comments/comments.json'

EVENTS__EVENT_INVITATIONS = 'events/event_invitations.json'
EVENTS__YOUR_EVENT_RESPONSES = 'events/your_event_responses.json'
EVENTS__YOUR_EVENTS = 'events/your_events.json'

FOLLOWS__FOLLOWED_PAGES = 'following_and_followers/followed_pages.json'
FOLLOWS__FOLLOWING = 'following_and_followers/following.json'
FOLLOWS__UNFOLLOWED_PAGES = 'following_and_followers/unfollowed_pages.json'

FRIENDS__FRIENDS = 'friends/friends.json'
FRIENDS__REJECTED_REQUESTS = 'friends/rejected_friend_requests.json'
FRIENDS__REMOVED = 'friends/removed_friends.json'
FRIENDS__SENT_REQUESTS = 'friends/sent_friend_requests.json'

GROUPS__MEMBERSHIP_ACTIVITY = 'groups/your_group_membership_activity.json'
GROUPS__ADMIN = 'groups/your_groups.json'
GROUPS__POSTS_AND_COMMENTS = 'groups/your_posts_and_comments_in_groups.json'

LIKES_AND_REACTIONS__PAGES = 'likes_and_reactions/pages.json'
LIKES_AND_REACTIONS__POSTS_AND_COMMENTS = 'likes_and_reactions/posts_and_comments.json'

# NOTE: Missing location data. This could be useful

MARKETPLACE__ITEMS_BOUGHT = 'marketplace/items_bought.json'
MARKETPLACE__ITEMS_SOLD = 'marketplace/items_sold.json'

#TODO: Figure out how to do messages
MESSAGES__SAMPLE = 'messages/inbox/33eee_ozf3zkkl9a/message_1.json'

# NOTE: This is missing one folder called `other_activity`.
# It contains pokes and other miscellanea
#TODO: Missing pages data. Do we need this?

PAYMENT_HISTORY = 'payment_history/payment_history.json'

#TODO: Missing photos and videos. Not sure who cares?

POSTS__OTHERS_PEOPLES_POSTS_TO_YOUR_TIMELINE = "posts/other_people's_posts_to_your_timeline.json"
POSTS__YOUR_POSTS = 'posts/your_posts.json'

#NOTE: This information is dense, and is likely best viewed as a raw JSON
PROFILE__PROFILE_INFO = 'profile_information/profile_information.json'
PROFILE__UPDATE_HISTORY = 'profile_information/profile_update_history.json'

SAVED_ITEMS_AND_COLLECTIONS = 'saved_items_and_collections/saved_items_and_collections.json'

SEARCH_HISTORY = 'search_history/your_search_history.json'

# There are some security login ones I didn't get around to doing

# %%
import pandas
from pandas.io.json import json_normalize
import json
from faker import Faker
import datetime
import time
import warnings

# %%
fake = Faker()
# Choose your own seed value.
# This ensures names will generate the same every time
fake.seed(25)
fakes_table = {}

# %%
def anonymized_json(json_data):
    print(json_data)
    return json_data

def _fake_name(input_name=None):
    name = fake.name()
    return _fake_table_lookup(input_name, name)

def _fake_email(input_email=None):
    email = fake.simple_profile()['mail']
    return _fake_table_lookup(input_email, email)

def _fake_title(input_title=None):
    max_len = max(5, (len(input_title) * 4)/3) if input_title else 15
    title = fake.text(max_nb_chars=max_len)[:-1].title()
    return _fake_table_lookup(input_title, title)

def _fake_text(input_text=None):
    max_len = max(5, (len(input_text) * 4)/3) if input_text else 24
    text = fake.text(max_nb_chars=max_len)[:-1]
    return _fake_table_lookup(input_text, text)

def _fake_timestamp(input_datetime, end_datetime=None, start_datetime=None):
    if input_datetime == 0:
        return 0
    timestamp = int(time.mktime(fake.past_date().timetuple()))
    return _fake_table_lookup(input_datetime, timestamp)

def _fake_phone(input_phone):
    phone = fake.phone_number()
    return _fake_table_lookup(input_phone, phone)

def _fake_url(input_url):
    url = fake.url()
    return _fake_table_lookup(input_url, url)

def _fake_ip(input_ip):
    ip = fake.ipv4_public()
    return _fake_table_lookup(input_ip, ip)

def _fake_location(input_loc):
    loc = "{}, {}".format(fake.city(), fake.state())
    return _fake_table_lookup(input_loc, loc)

def _fake_address(input_addr):
    address = fake.address().replace('\n', ' ')[:-6]
    return _fake_table_lookup(input_addr, address)

def _fake_latitude(input_lat):
    lat = fake.latitude()
    return _fake_table_lookup(input_lat, lat)

def _fake_longitude(input_lon):
    lon = fake.longitude()
    return _fake_table_lookup(input_lon, lon)

def _fake_bool():
    return fake.boolean()

def _fake_table_lookup(key, value):
    if key is None:
        return value
    elif key not in fakes_table:
        fakes_table[key] = value
    else:
        value = fakes_table[key]
    return value

# %%
print_missing_key_stack = True

def write_cleaned_file(filename):
    with open('../facebook-data/' + filename) as f:
        data = json.load(f)
    with open('../datastructures.json') as d:
        cleaning_rules = json.load(d)[filename]
    _apply_rules_to_json(cleaning_rules, data)
    return data
    
def _apply_rules_to_json(rules, data={}):
    for key in data.keys():
        if key not in rules:
            warning = "(Missing key: {})".format(key)
            if print_missing_key_stack:
                print(warning)
                return -1
            else:
                warnings.warn(warning)
                continue
        r_val = rules[key]
        d_val = data[key]
        x = 0
        if r_val is None:
            return        
        if isinstance(d_val, dict):
            if _apply_rules_to_json(r_val, d_val) == -1:
                print(key)
                return
        elif isinstance(d_val, list):
            for i in range(len(d_val)):
                data_value = d_val[i]
                if isinstance(data_value, dict):                    
                    if _apply_rules_to_json(r_val[0], data_value) == -1:
                        print(key)
                        return
                else:
                    d_val[i] = _apply_rule_to_value(r_val[0], data_value)
        else:
            data[key] = _apply_rule_to_value(r_val, d_val)

            
def _apply_rule_to_value(rule, value):
        if rule == "NAME":
            return _fake_name(value)
        elif rule == "TIMESTAMP":
            return _fake_timestamp(value)
        elif rule == "EMAIL":
            return _fake_email(value)
        elif rule == "PHONE":
            return _fake_phone(value)
        elif rule == "TITLE":
            return _fake_title(value)
        elif rule == "TEXT":
            return _fake_text(value)
        elif rule == "URL":
            return _fake_url(value)
        elif rule == "URI":
            return "photos_and_videos/your_posts/some_local_path.jpg"
        elif rule == "IP_ADDRESS":
            return _fake_ip(value)
        elif rule == "LOCATION":
            return _fake_location(value)
        elif rule == "ADDRESS":
            return _fake_address(value)
        elif rule == "LAT":
            return _fake_latitude(value)
        elif rule == "LON":
            return _fake_longitude(value)
        elif rule == "BOOL":
            return _fake_bool()
        # Allow overriding for specific strings
        elif "CUSTOM:" in rule:
            return rule.replace('CUSTOM:','') + "**"
        # For documentation sake, write in which ones we manually tweak
        elif rule == "MANUAL":
            return "MANUAL_OVERWRITE"
        elif rule == "IGNORE":
            return
        else:
            warnings.warn("Unable to handle rule '{}'".format(rule))
            
data = write_cleaned_file(SEARCH_HISTORY)
data
# Out:
# {'searches': [{'data': [{'text': 'Series fact.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Series fact.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557892800, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1558670400, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1557720000, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1558238400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Nicholas Ferguson'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Can best perform.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Test'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Entire trade.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559188800, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hot Play Evening Surface Stage'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Tonight industry available what off rule.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Buy Situation'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Nice past clear.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559188800, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Local Student Mother Personal. Job Congress Fire Ball'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rise effort vote course wide.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558929600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Prepare many.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'While.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Right blue.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559102400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sarah Figueroa'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Floor home ten man.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Can rock himself.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Religious.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Medical late behind.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Window clear garden.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Medical late behind.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Window clear garden.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Movie cold better.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Threat oil get find coach.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wind subject.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Social.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Social.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Social.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Far involve power time compare.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558843200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'As local realize with town story.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558324800, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'As local realize with town story.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wind subject.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Knowledge draw if live reason month wide.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jason Hodges'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Trip trade catch.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Such sign place.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Agreement.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Leg message.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Late put rise.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Politics.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Follow issue.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Lori Reed'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Clearly leave.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Successful simple.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Expect purpose.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Water send share.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Christopher Rodriguez'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Agency practice.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Require lot may.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'We yet keep.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Herself environment.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Son someone walk system.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kenneth Spencer'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Surface city.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kevin Mahoney'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Again house knowledge.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559361600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Soldier difference table.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Service message.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Floor major in.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Town by example fish.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Audrey Blake'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Effect mother go.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Elizabeth Hernandez'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Elizabeth Hernandez'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kathryn Richard'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Discuss threat.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557633600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Father Ahead Nation Good Loss Rest Also Teach'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Radio former could.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Per.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558584000, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Per.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Per.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Perhaps only yes.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sport hold.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hour Mr hour.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Unit within today.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558843200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Albert Olson'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Participant.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Improve.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'College what.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559188800, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wall her long.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Court.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Carry face.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Court.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Carry face.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Soldier difference table.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Move forget month able.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Real bill fund.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Week'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Word.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Represent.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Audrey Blake'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Effect mother go.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Learn through.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hear.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Admit party table player.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Those season who.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559016000, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1557115200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Moment piece.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'The light.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Value draw.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ever.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Score Outside Hit My Outside Act Gas'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Do production.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'The light.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557547200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Test'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Entire trade.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Try current.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Laugh.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Fight likely stand.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Soldier difference table.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Gregory Cabrera'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'How network data.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'How network data.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Peter Martinez'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Quite.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Without third grow.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Teach fly author address meeting security lay.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Along man hundred go few.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Often once positive avoid.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rule challenge if.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Open item town base.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Them.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Different.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Former listen.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Option week.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Figure remember especially.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Andrea Murphy'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Majority hot life.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Cover.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Song.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Pick area fall.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jesus Manning'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ask reason.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Scott Walker'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Success reach.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Read follow.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Happen safe.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Read follow.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Happen safe.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Standard space assume bag.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Purpose do.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'When stock could.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Send.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Expect.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Process join.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Success reach.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Increase realize your available.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sister key option.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Step energy.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Evidence itself.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557892800, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Much.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Mathew Gibbs'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wish must.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Fire result.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Game.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Much.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Knowledge draw if live reason month wide.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Dylan Harris'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'News top.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Anthony Little'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'All of rule.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Camera least score.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Above show.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Myself lead.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Tiffany Mclaughlin'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Top such.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Product head.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Very thousand.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kathryn Richard'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Discuss threat.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'PM morning.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Be statement.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Receive.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Forward grow red reality.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Season always financial whatever.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'May pick popular hand hold meeting.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Owner yard standard we turn agree.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Picture cost hit apply white.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'John Lawson'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Player side prove end.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Detail son.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'John Lawson'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Player side prove end.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Run tell rule fine form.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Skin source heavy.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Report effect Democrat task.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'John Lawson'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Player side prove end.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Suggest unit growth institution.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Medical across Mrs will.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Force left story yet new.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Professor staff run project.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Site that move theory hair whether.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Consider work off.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Put night program wind.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Us cover never.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Central work lawyer degree.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Detail son.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'View too.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559275200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Site that move theory hair whether.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Paper Sort Me Beyond Hope'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'During role.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Erica Barry'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Erica Barry'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Argue determine.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Think government research.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Brandon Nicholson'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Line red rich through.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Attorney nice.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Big boy.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Matthew Barnett'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Reflect.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557979200, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1559102400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Amber Juarez'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Including.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Carl Myers'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Design country.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Cup now me born.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Apply would.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557979200, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1558065600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Peter Martinez'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Quite.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557288000, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Unit board enough rise.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Unit board enough rise.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Unit board enough rise.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Unit board enough rise.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Energy tend billion.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Appear once world above cell risk cultural.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hand each American surface see care human.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Try any response positive inside job.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Try any response positive inside job.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Try any response positive inside job.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'His media cultural.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Much feeling project consumer.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Security nor design.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sort yet space tell west world.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Direction herself today.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Probably moment work cup.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Federal another voice safe say.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Prove name charge skin girl along future.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Same Film'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Assume nor.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Woman hotel same.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Her anyone line.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558670400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Audrey Blake'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Effect mother go.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557633600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ricky Avila'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Industry before.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Matthew Nguyen'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Popular near suggest two together game.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Process factor.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Audrey Blake'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Effect mother go.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Mission price else itself.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kim Adams'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Financial recently cell.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559275200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Table.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Food.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Anthony Soto'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Worry authority.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ana Norris'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Past cup race.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Matthew Nguyen'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Standard fish.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557547200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Detail son.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Stuff shoulder teach personal.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558238400, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1558670400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Special she understand material your.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Speech campaign grow fund should. Like song rock market change.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Around difficult.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rule challenge if.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Yes third contain song.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Seem imagine.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Congress wish.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Price decide.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Affect type.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Candidate.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Cultural might Mr.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Seem Budget Learn Dream'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558065600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Entire.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Require.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Full blood answer.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Entire.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1558584000, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Middle we.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Erin Flores'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Cause lawyer Mrs.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Home far.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Prevent.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Across into.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Risk Movie Represent'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559361600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Offer yard respond decide.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Amanda Kelly PhD'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Seem Budget Learn Dream'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Andrea Yates'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ball seek administration old production news summer discuss.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557201600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'All customer.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Push similar.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Memory recognize.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557288000, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1558152000, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Adrienne Davis'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Crime feel wrong.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Degree bill Democrat.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'That yet perform.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'When All Believe House'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Minute drug theory.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Detail son.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Detail son.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Patrick Webster'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Seem Budget Learn Dream'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Oil attorney son such.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Joan Walker'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Full edge not.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Michael Decker'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557720000, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Food enjoy career.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Let debate factor.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Focus and real six feel imagine year. Organization approach work hope.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Gas general phone.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'John Lawson'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Amanda Miller'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Robin Mcgrath'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Faith Fields'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Eugene Clark'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Daniel Harper'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Matthew Barnett'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rebecca Allen'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kevin Mahoney'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'William Davenport'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jason Jones'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Eugene Clark'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Coach president.'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Mission citizen fly somebody mother. Argue board owner turn.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Reduce economy view today bill.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Reduce economy view today bill.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559275200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Factor opportunity culture while with base less.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557028800, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Center name.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Center name.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Center name.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Risk Movie Represent'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Song movement across try less.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Teresa Hancock'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Best drop visit view.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ana Norris'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ana Norris'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Above property.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ana Norris'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ana Norris'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Chair.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Angela Thornton'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Maybe alone scene as today. Guy want election process lot.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Store church somebody four. Eight last fill age political outside.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Meet world serve around.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Religious bed music opportunity general far. Race single hear.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Base way imagine stand. Beat others their walk finish herself.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sometimes member turn.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sometimes member turn.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hannah Matthews'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Military lawyer.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Two on house admit.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Individual east three.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Artist window sort media. Attention nearly news no.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Anita Nelson'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Deep somebody up.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Poor here light. Four authority police. Quickly sing power.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Debate myself.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557806400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Billy Mcpherson'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Soldier test fish.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Amber Juarez'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Fear buy standard art Congress institution. Blue face why close.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Cassandra Wilkinson'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rock.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Offer.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Upon Free Enjoy Citizen'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ever sometimes me around.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'William Garcia'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Happen appear.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Believe social want term. Offer official pull capital mother.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Eduardo Myers'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Lawyer science deep include.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'From move fear.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Social note important hot. Down control southern stay radio hope set.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Our Season'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Our Season'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559361600, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Name understand discussion ago. Build her father.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Gina Kerr'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rebecca Allen'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jacqueline Jenkins'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jacob Miller'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Same Film'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1557115200, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Same Film'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Crime money color continue task official.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Mission price else itself.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Success from you.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Truth apply best most.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Best us officer.'}],
# ...
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'After Perform'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Mark Palmer'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Later deep.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Natalie Daniel'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Susan Glass'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sarah Keith'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Later deep.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jonathan Duarte'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Nicole Bailey'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Robert Flores'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Clear attention.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ricky Avila'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Brenda Wright'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Angel Bean'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Tree identify.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jo Smith'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Any Magazine Item'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Voice discuss.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Five Tonight Including Cover Between'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Pick Instead Be Paper Interest Summer. Beyond Thing Conference Itself Piece'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hear I trade join.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hear I trade join.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Christopher Burgess'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Desiree Rogers'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Into top other election sea walk.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kevin Mahoney'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kevin Mahoney'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'New.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ruth Burns'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Agree Fight Check Hair'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Medical hope.'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'After Perform'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Send.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'That whatever.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sarah Figueroa'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Agree Fight Check Hair'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Just'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Just'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Soldier everyone first.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Just'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Thank Republican suggest.'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Long consider head.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Across able.'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Scott Gonzalez'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wall value nothing.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'April Jones'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'After Perform'}],
#    'timestamp': 1559188800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Real bill fund.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Move forget month able.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Just'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Glass Direction Positive So Front'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'National stop.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Alexis Morris'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Phone director fast citizen.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Area school five ok.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Human letter tell size.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Traditional can.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'High bag red here. Matter chance risk number return discussion parent.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Eduardo Myers'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Amount whom.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Andrea Murphy'}],
#    'timestamp': 1558238400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'After Perform'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Their nation beat degree crime reach.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Their nation beat degree crime reach.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Statement.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Federal tree.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Song man call where.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Relationship'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kathy Johnson'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Discover your.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Discover your.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Work ground occur.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Really call home.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Really call home.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Yourself consider.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wait fall stock fly.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Share position.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Audrey Blake'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Phyllis Swanson'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Katrina Bell'}],
#    'timestamp': 1559275200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Share position.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Amanda Miller'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Phyllis Swanson'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jo Smith'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jo Smith'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Small girl difficult son more.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Loss stuff.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Kyle Rodriguez'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sophia Scott'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Pull toward.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Glass Direction Positive So Front'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Guess energy now.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Guess energy now.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Hot over smile beat.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Discuss news.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Compare force note as.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'William Davenport'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'When All Believe House'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Few.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Jennifer Herrera'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Assume commercial box easy. Few thus pattern enough who.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Major voice these partner.'}],
#    'timestamp': 1556942400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Toward prove society.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Authority sure painting expect.'}],
#    'timestamp': 1557028800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Quickly.'}],
#    'timestamp': 1557720000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Them.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Or.'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Or.'}],
#    'timestamp': 1558929600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Body.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ricky Smith'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Group.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Treat daughter.'}],
#    'timestamp': 1558670400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Care development.'}],
#    'timestamp': 1557201600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Concern.'}],
#    'timestamp': 1557806400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Away.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Away.'}],
#    'timestamp': 1558065600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Treat daughter.'}],
#    'timestamp': 1558152000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Around.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Check.'}],
#    'timestamp': 1558584000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Lisa Frank'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Destiny Kramer'}],
#    'timestamp': 1558843200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Remain political.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Group.'}],
#    'timestamp': 1558411200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Green tell.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Away.'}],
#    'timestamp': 1559016000,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Food environmental.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Window.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ago.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'True.'}],
#    'timestamp': 1557892800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Available.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Ricky Smith'}],
#    'timestamp': 1558324800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Final.'}],
#    'timestamp': 1559102400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Point act.'}],
#    'timestamp': 1557374400,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Point act.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'During.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Wife.'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Large.'}],
#    'timestamp': 1559361600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Real.'}],
#    'timestamp': 1557547200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Scott Gonzalez'}],
#    'timestamp': 1557633600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Social.'}],
#    'timestamp': 1557115200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Natural rock.'}],
#    'timestamp': 1558756800,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Long.'}],
#    'timestamp': 1558497600,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Sure.'}],
#    'timestamp': 1557288000,
#    'title': 'You searched for XYZ**'},
#   {'timestamp': 1559361600, 'title': 'You searched for XYZ**'},
#   {'timestamp': 1559102400, 'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Under.'}],
#    'timestamp': 1557979200,
#    'title': 'You searched for XYZ**'},
#   {'data': [{'text': 'Rather do.'}],
#    'timestamp': 1557460800,
#    'title': 'You searched for XYZ**'},
#   ...]}

# %%
def json_with_ignored_keys(filename):
    with open('../facebook-data/' + filename) as f:
        data = json.load(f)
    (ignored_keys, flatten_keys) = _keys_for_file(filename)
    for k in ignored_keys:
        data = data[k]
    return data

def json_as_dataframe(filename):
    data = json_with_ignored_keys(filename)
    (_, flatten_keys) = _keys_for_file(filename)
    # We want to flatten the `data` value a lot of these have    
    for d in data:
        d = _collapse_keys(d, flatten_keys)
                
    pd = pandas.DataFrame.from_dict(data)
    return json_normalize(data)


def _collapse_keys(row, collapse_keys):
    for ck in collapse_keys:
        if ck in row and isinstance(row[ck], list) and len(row[ck]) == 1:
            row[ck] = _collapse_keys(row[ck][0], collapse_keys)
    return row

def _keys_for_file(filename):
    ig_keys = []
    flatten_keys = []
    if filename is ABOUT__ADDRESS_BOOK:
        ig_keys = ['address_book', 'address_book']
        
    if filename is ADS__INTERACTED_WITH:
        ig_keys = ['history']
        
    if filename is APPS_AND_WEBSITES:
        ig_keys = ['installed_apps']
        
    if filename is COMMENTS:
        ig_keys = ['comments']
        flatten_keys = ['data']
        
    if filename is EVENTS__YOUR_EVENT_RESPONSES:
        # NOTE: this can be changed to `events_declined` or `events_interested`
        ig_keys = ['event_responses', 'events_joined'] 
    if filename is EVENTS__YOUR_EVENTS:
        ig_keys = ['your_events']
        
    if filename is FOLLOWS__FOLLOWED_PAGES:
        ig_keys = ['pages_followed']
        flatten_keys = ['data']
    if filename is FOLLOWS__FOLLOWING:
        ig_keys = ['following']
    if filename is FOLLOWS__UNFOLLOWED_PAGES:
        ig_keys = ['pages_unfollowed']
        flatten_keys = ['data']

    if filename is FRIENDS__FRIENDS:
        ig_keys = ['friends']
    if filename is FRIENDS__REJECTED_REQUESTS:
        ig_keys = ['rejected_requests']
    if filename is FRIENDS__REMOVED:
        ig_keys = ['deleted_friends']
    if filename is FRIENDS__SENT_REQUESTS:
        ig_keys = ['sent_requests']
        
    if filename is GROUPS__PENDING_POSTS:
        ig_keys = ['pending_posts']
    if filename is GROUPS__MEMBERSHIP_ACTIVITY:
        ig_keys = ['groups_joined']
        flatten_keys = ['attachments', 'data']
    if filename is GROUPS__ADMIN:
        ig_keys = ['groups_admined']
    if filename is GROUPS__POSTS_AND_COMMENTS:
        ig_keys = ['group_posts', 'activity_log_data']
        flatten_keys = ['data']

    if filename is LIKES_AND_REACTIONS__PAGES:
        ig_keys = ['page_likes']
    if filename is LIKES_AND_REACTIONS__POSTS_AND_COMMENTS:
        ig_keys = ['reactions']
        flatten_keys = ['data']
        
    if filename is MARKETPLACE__ITEMS_BOUGHT:
        ig_keys = ['items_buying']
    if filename is MARKETPLACE__ITEMS_SOLD:
        ig_keys = ['items_selling']
        
    if filename is MESSAGES__SAMPLE:
        ig_keys = ['messages']
        
    if filename is PAYMENT_HISTORY:
        ig_keys = ['payments', 'payments']
        
    if filename is POSTS__OTHERS_PEOPLES_POSTS_TO_YOUR_TIMELINE:
        ig_keys = ['wall_posts_sent_to_you']
        flatten_keys = ['data']
    if filename is POSTS__YOUR_POSTS:
        ig_keys = ['status_updates']
        flatten_keys = ['attachments', 'data'] 
        
    if filename is SAVED_ITEMS_AND_COLLECTIONS:
        ig_keys = ['saves_and_collections']
        flatten_keys = ['attachments', 'data'] 

    if filename is SEARCH_HISTORY:
        ig_keys = ['searches']
        flatten_keys = ['data']
        
    return (ig_keys, flatten_keys)

# %%
a = json_as_dataframe(APPS_AND_WEBSITES)
a.sample(n=1)
# Out:
#     added_timestamp    name
# 17       1477976626  Bumble
